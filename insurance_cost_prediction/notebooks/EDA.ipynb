# %% [markdown]
# #### Import required libraries

# %%
import pandas as pd 
import numpy as np 
import json 
from pathlib import Path

# %% [markdown]
# #### Define the working base directory

# %%
BASE_DIR = Path.cwd().parent

# %% [markdown]
# #### Identify the path to config and load it's variables from json

# %%
CONFIG_PATH = BASE_DIR/"config"/"insurance_config.json"
with open(CONFIG_PATH) as m: 
    config = json.load(m)

# %% [markdown]
# #### Identify the path where the raw dataset is stored and load it

# %%
RAW_DATASET_PATH = BASE_DIR/config["raw_path"]
raw_dataset = pd.read_csv(RAW_DATASET_PATH)
raw_dataset.sample(5)
# Out:
#      age     sex    bmi  children smoker     region     charges
# 478   21    male  36.85         0     no  southeast   1534.3045
# 339   46  female  27.72         1     no  southeast   8232.6388
# 141   26    male  32.49         1     no  northeast   3490.5491
# 789   62  female  29.92         0     no  southeast  13457.9608
# 774   41    male  34.20         2     no  northwest   7261.7410

# %% [markdown]
# #### Check for missing values and the data types

# %%
raw_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# #### Identify unique values in the categorical columns

# %%
raw_dataset["sex"].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
raw_dataset["smoker"].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
raw_dataset["region"].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)
