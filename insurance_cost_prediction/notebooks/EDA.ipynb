# %% [markdown]
# #### Import necessary libraries

# %%
import pandas as pd 
import numpy as np
import json
from pathlib import Path 
from dotenv import load_dotenv

# %% [markdown]
# #### Environmental setup and configuration loading

# %%
# Load .env variables and define the base working directory
load_dotenv()
BASE_DIR = Path.cwd().parent

# Define the configuration path and load the configuration variables from the json file
CONFIG_PATH = BASE_DIR/"config"/"insurance_config.json"
with open(CONFIG_PATH) as m:
    config = json.load(m)

# Define the path to the raw dataset 
RAW_PATH = BASE_DIR/config["raw_path"]

# %% [markdown]
# #### Import the raw dataset

# %%
dataset = pd.read_csv(RAW_PATH)
dataset.sample(5)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1299   19  female  25.745         1     no  northwest   2710.82855
# 1231   20  female  21.800         0    yes  southwest  20167.33603
# 135    22  female  28.050         0     no  southeast   2155.68150
# 847    23    male  50.380         1     no  southeast   2438.05520
# 1101   53    male  28.600         3     no  southwest  11253.42100

# %% [markdown]
# #### Exploratory data analysis

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
dataset["sex"].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
dataset["smoker"].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
dataset["region"].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)
