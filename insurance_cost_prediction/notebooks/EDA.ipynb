# %% [markdown]
# #### Import the required libraries

# %%
import pandas as pd 
import numpy as np 
import json
from dotenv import load_dotenv
from pathlib import Path

# %% [markdown]
# #### Load .env variables and define the working base directory

# %%
load_dotenv()
BASE_DIR = Path.cwd().parent

# %% [markdown]
# #### Define the path to config and load the config variables from json

# %%
CONFIG_PATH = BASE_DIR/"config"/"insurance_config.json"
with open(CONFIG_PATH) as m:
    config = json.load(m)

# %% [markdown]
# #### Define the path to the raw dataset

# %%
RAW_PATH = BASE_DIR/config["raw_path"]

# %% [markdown]
# #### Load the raw dataset

# %%
raw_dataset = pd.read_csv(RAW_PATH)
raw_dataset.sample(5)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 813    28    male  22.515         2     no  northeast   4428.88785
# 1126   55    male  29.900         0     no  southwest  10214.63600
# 895    61  female  44.000         0     no  southwest  13063.88300
# 662    32  female  31.540         1     no  northeast   5148.55260
# 806    40  female  41.420         1     no  northwest  28476.73499

# %% [markdown]
# #### Check for missing values and understand the data types

# %%
raw_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# #### Chech unique values in the categorical columns

# %%
raw_dataset["sex"].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
raw_dataset["smoker"].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
raw_dataset["region"].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)
