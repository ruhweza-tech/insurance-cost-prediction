# %% [markdown]
# ## Import necessary libraries

# %%
import pandas as pd 
import numpy as np
from pathlib import Path
import json 
from dotenv import load_dotenv

# %%
# Load the .env variables and define the base directory two levels up
load_dotenv()
BASE_DIR = Path.cwd().parent

# Define the config path and load config variables from json 
CONFIG_PATH = BASE_DIR/"config"/"insurance_config.json"
with open(CONFIG_PATH) as m:
    config = json.load(m)

# Define the raw dataset path and clean data folder
RAW_PATH = BASE_DIR/config["raw_path"]

# %% [markdown]
# ## Import dataset

# %%
#raw_path = r"C:\Users\ruhwemug\ML_Projects\my_project\insurance_cost_prediction\data\raw\insurance.csv"
dataset = pd.read_csv(RAW_PATH)
dataset.sample(5)
# Out:
#       age     sex    bmi  children smoker     region      charges
# 1223   20  female  24.42         0    yes  southeast  26125.67477
# 965    35    male  27.10         1     no  southwest   4746.34400
# 1182   25  female  30.30         0     no  southwest   2632.99200
# 141    26    male  32.49         1     no  northeast   3490.54910
# 1013   48    male  32.30         1     no  northwest   8765.24900

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
dataset["sex"].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
dataset["smoker"].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
dataset["region"].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)
