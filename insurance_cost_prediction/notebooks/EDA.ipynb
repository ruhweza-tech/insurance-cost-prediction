# %% [markdown]
# ### Import necessary libraries

# %%
import pandas as pd 
from pathlib import Path 
import numpy as np 
from dotenv import load_dotenv
import json

# %% [markdown]
# ### Environment setup and configuration loading

# %%
# Load the .env variables and define the base working directory 
load_dotenv()
BASE_DIR = Path.cwd().parent

# Define the configuration path and read configuration variables from the json file
CONFIG_PATH = BASE_DIR/"config"/"insurance_config.json"
with open(CONFIG_PATH) as m:
    config = json.load(m)

# Define the path to the raw data 
RAW_PATH = BASE_DIR/config["raw_path"]

# %% [markdown]
# ### Loading the raw dataset

# %%
dataset = pd.read_csv(RAW_PATH)
dataset.sample(5)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 326    27  female  23.210         1     no  southeast   3561.88890
# 1320   31    male  31.065         3     no  northwest   5425.02335
# 245    54    male  30.020         0     no  northwest  24476.47851
# 27     55  female  32.775         2     no  northwest  12268.63225
# 1283   18    male  30.030         1     no  southeast   1720.35370

# %% [markdown]
# ### Understanding the type of data in the dataset and if there any missing values

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# ### Display unique values in the following columns in the dataset

# %%
dataset["sex"].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
dataset["smoker"].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
dataset["region"].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)
